# %%
import pandas as pd

# %%
df = pd.read_csv("./clinical.cases_selection.2022-10-25 copy/clinical.tsv", sep="\t")

# %%
df.groupby("primary_diagnosis")['case_id'].count()
# Out:
# primary_diagnosis
# Adenocarcinoma with mixed subtypes                            216
# Adenocarcinoma, NOS                                           859
# Basaloid squamous cell carcinoma                               28
# Bronchio-alveolar carcinoma, mucinous                          10
# Bronchiolo-alveolar adenocarcinoma, NOS                         6
# Bronchiolo-alveolar carcinoma, non-mucinous                    38
# Clear cell adenocarcinoma, NOS                                  4
# Micropapillary carcinoma, NOS                                   6
# Papillary adenocarcinoma, NOS                                  44
# Papillary squamous cell carcinoma                               8
# Solid carcinoma, NOS                                           12
# Squamous cell carcinoma, NOS                                 1044
# Squamous cell carcinoma, keratinizing, NOS                     26
# Squamous cell carcinoma, large cell, nonkeratinizing, NOS       6
# ...

# %%
df
# Out:
#                                    case_id case_submitter_id project_id  \
# 0     34040b83-7e8a-4264-a551-b16621843e28      TCGA-05-4244  TCGA-LUAD
# 1     34040b83-7e8a-4264-a551-b16621843e28      TCGA-05-4244  TCGA-LUAD
# 2     b2285924-9813-4f46-bb8f-91a0efd8a9b6      TCGA-73-4668  TCGA-LUAD
# 3     b2285924-9813-4f46-bb8f-91a0efd8a9b6      TCGA-73-4668  TCGA-LUAD
# 4     af611aef-c369-4941-959e-a68838e2b2f2         C3N-03210    CPTAC-3
# ...                                    ...               ...        ...
# 2304  0e2ee54a-51c9-4868-842d-a2a1c1cfb016      TCGA-21-1082  TCGA-LUSC
# 2305  0e2ee54a-51c9-4868-842d-a2a1c1cfb016      TCGA-21-1082  TCGA-LUSC
# 2306  068174d5-0001-421a-bec9-80f2519051d4         C3L-03268    CPTAC-3
# 2307  fb79c491-7b01-42ae-8369-8364e442e31b      TCGA-44-2665  TCGA-LUAD
# 2308  fb79c491-7b01-42ae-8369-8364e442e31b      TCGA-44-2665  TCGA-LUAD
#
#      age_at_index age_is_obfuscated cause_of_death cause_of_death_source  \
# ...
